# %%
# Improt the necessary libraries
import itertools
import xarray as xr
import rasterio
import pandas as pd
import geopandas as gpd
import rioxarray
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import cm as colormap
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
import matplotlib.patches as mpatches
from sklearn.metrics import confusion_matrix
import numpy as np

# %%
WTE_FOLDER = "/mnt/drive/AI4EBV/INPUTS/WTE/"

# Wte table
WTE_TABLE = WTE_FOLDER + "Tables/Realm_WE_attribute_Table_DraftSort_colors.csv"

# %%
wte_table = pd.read_csv(WTE_TABLE, sep=',')
wte_table
# Out:
#       Unnamed: 0     LF_Name       LC_Name           Temp_Moist  RealmWE_ID  \
# 0              1       Hills      Cropland   Sub Tropical Moist        5267
# 1              2       Hills        Forest     Sub Tropical Dry        5290
# 2              3       Hills    Settlement       Tropical Moist        3407
# 3              4       Hills      Cropland  Sub Tropical Desert        5349
# 4              5       Hills     Grassland     Sub Tropical Dry        5279
# ...          ...         ...           ...                  ...         ...
# 1776        1777  Tablelands  Snow and Ice          Polar Moist        5011
# 1777        1778  Tablelands     Grassland            Polar Dry        6038
# 1778        1779  Tablelands     Grassland          Polar Moist        1026
# 1779        1780  Tablelands    Settlement         Boreal Moist        5094
# 1780        1781  Tablelands     Shrubland          Polar Moist        1024
#
#       WE_ID  Realm_ID  RealmClass  LF_Class  MoistClass  ...  \
# 0       267      5000           5         2           3  ...
# 1       290      5000           5         2           2  ...
# 2       407      3000           3         2           3  ...
# 3       349      5000           5         2           1  ...
# 4       279      5000           5         2           2  ...
# ...     ...       ...         ...       ...         ...  ...
# 1776     11      5000           5         3           3  ...
# 1777     38      6000           6         3           2  ...
# 1778     26      1000           1         3           3  ...
# 1779     94      5000           5         3           3  ...
# 1780     24      1000           1         3           3  ...
#
#                                    WEcosystm  \
# 0       Sub Tropical Moist Cropland on Hills
# 1           Sub Tropical Dry Forest on Hills
# 2         Tropical Moist Settlement on Hills
# 3      Sub Tropical Desert Cropland on Hills
# 4        Sub Tropical Dry Grassland on Hills
# ...                                      ...
# 1776  Polar Moist Snow and Ice on Tablelands
# 1777       Polar Dry Grassland on Tablelands
# 1778     Polar Moist Grassland on Tablelands
# 1779   Boreal Moist Settlement on Tablelands
# 1780     Polar Moist Shrubland on Tablelands
#
#                                            RWEcosystm LandC_Type  Code  \
# 0       Nearctic Sub Tropical Moist Cropland on Hills  Converted  4321
# 1           Nearctic Sub Tropical Dry Forest on Hills    Natural  4223
# 2      Australasia Tropical Moist Settlement on Hills  Converted  5325
# 3      Nearctic Sub Tropical Desert Cropland on Hills  Converted  4121
# 4        Nearctic Sub Tropical Dry Grassland on Hills    Natural  4224
# ...                                               ...        ...   ...
# 1776  Nearctic Polar Moist Snow and Ice on Tablelands    Natural  6338
# 1777      Neotropic Polar Dry Grassland on Tablelands    Natural  6234
# 1778   Afrotropic Polar Moist Grassland on Tablelands    Natural  6334
# 1779   Nearctic Boreal Moist Settlement on Tablelands  Converted  1335
# 1780   Afrotropic Polar Moist Shrubland on Tablelands    Natural  6332
#
#          CR_HEX     LC_HEX     LF_HEX TempMoistClass  WTE_code  WTE_HEX
# 0     #FCC24E66  #B5D99EFF  #7DC756B2             12      1212  #bac860
# 1     #FCE30066  #267300FF  #7DC756B2             11      3211  #a0c324
# 2     #66240566  #8A4343FF  #7DC756B2             15      5215  #766e32
# 3     #FFF7BA66  #B5D99EFF  #7DC756B2             10      1210  #bbdd8b
# 4     #FCE30066  #789E60FF  #7DC756B2             11      4211  #afcb35
# ...         ...        ...        ...            ...       ...      ...
# 1776  #BFBFBF66  #B4B6CCFF  #8B6CE0B2             18      8318  #a79bcf
# 1777  #DBDBDB66  #789E60FF  #8B6CE0B2             17      4317  #a8a1c7
# 1778  #BFBFBF66  #789E60FF  #8B6CE0B2             18      4318  #9c96bc
# 1779  #2C8EBF66  #8A4343FF  #8B6CE0B2              3      5303  #6572b7
# 1780  #BFBFBF66  #A8A800FF  #8B6CE0B2             18      2318  #a598aa
#
# [1781 rows x 25 columns]

# %% [markdown]
# ## WTE Ecosystem map from single WTE component

# %% [markdown]
# Read the files generated during the validation of the components

# %%
TEMPERATURE_LAYER = "./wte_temp_UTM_Himalaya.nc"
MOISTURE_LAYER    = "./wte_moist_UTM_Himalaya.nc"
LANDFORM_LAYER    = "./wte_lf_UTM_Himalaya.nc"
LANDCOVER_LAYER   = "./wte_lc_UTM_Himalaya.nc"

# %%
temp = xr.open_dataset(TEMPERATURE_LAYER).to_array()[0]
moist = xr.open_dataset(MOISTURE_LAYER).to_array()[1]
landform = xr.open_dataset(LANDFORM_LAYER).to_array()[1]
landcover = xr.open_dataset(LANDCOVER_LAYER).to_array()[1]
landcover_array  = np.copy(landcover.values)
landform_array  = np.copy(landform.values)
moisture_array  = np.copy(moist.values)
temperature_array  = np.copy(temp.values)

# %%
# Utility function to convert HEX RGB colors to R,G,B in uint8 (0-255)
def hex_to_rgb(hex_color_string):
    hex_color_string = hex_color_string.lstrip('#')
    return tuple(int(hex_color_string[i:i+2], 16) for i in (0, 2, 4))

# %%
ecosystem_R  = np.ones(landcover_array.shape)*255
ecosystem_G  = np.ones(landcover_array.shape)*255
ecosystem_B  = np.ones(landcover_array.shape)*255

number_of_valid_pixels = np.count_nonzero(landcover_array)

ecosystem_map_wte  = np.zeros(landcover_array.shape)

wte_labels = {}

tot_class_numb = 0

for lc in range(1,9): # landcover
    lc_mask = landcover_array==lc
    color0 = wte_table.loc[wte_table['LC_Class']==lc]
    lc_class_value = lc
    for lf in range(1,6):
        lf_mask = landform_array==lf
        color1 = color0.loc[wte_table['LF_Class']==lf]
        lf_class_value = lf*10
        for mois in range(1,4):
            moist_mask = moisture_array==mois
            color2 = color1.loc[wte_table['MoistClass']==mois]
            moist_class_value = mois*100
            for t in range(0,6):
                temperature_mask = temperature_array==t
                if t==0:
                    color3 = color2.loc[wte_table['TempClass']==6]
                    temp_class_value = 6*1000
                else:
                    color3 = color2.loc[wte_table['TempClass']==t]
                    temp_class_value = t*1000
                try:
                    color3['WTE_HEX'].values[0]
                    rgb_color = hex_to_rgb(color3['WTE_HEX'].values[0])
                    ecosystem_label = color3['WEcosystm'].values[0]
                    ecosystem_mask = lc_mask*lf_mask*moist_mask*temperature_mask
                    if (np.sum(ecosystem_mask)>0):
                        tot_class_numb +=1
#                         if ((np.sum(ecosystem_mask) / number_of_valid_pixels)>0.01): # This additional condition is used if we don't want to consider classes covering less than 1% of the area
                        ecosystem_R[ecosystem_mask] = rgb_color[0]
                        ecosystem_G[ecosystem_mask] = rgb_color[1]
                        ecosystem_B[ecosystem_mask] = rgb_color[2]
                        ecosystem_class = temp_class_value + moist_class_value + lf_class_value + lc_class_value
                        ecosystem_map_wte[ecosystem_mask] = ecosystem_class
                        wte_labels[str(int(ecosystem_class))] = ecosystem_label
                except:
                    continue

wte_ecosystem = np.stack([ecosystem_R,ecosystem_G,ecosystem_B],axis=2)

# %%
plt.imshow(wte_ecosystem.astype(np.uint8),cmap='brg')

# %% [markdown]
# ## WTE Ecosystem map from global layers
# Temperature: Worldclim, Moisture: CGIAR, Landform: Merit, Land Cover: Copernicus Global Land Cover ECOSYSTEM MAP

# %%
TEMPERATURE_LAYER = "./worldclim_to_wte_temp_UTM_Himalaya.nc"
MOISTURE_LAYER    = "./cgiar_to_wte_moist_UTM_Himalaya.nc"
LANDFORM_LAYER    = "./merit_to_wte_lf_UTM_Himalaya.nc"
LANDCOVER_LAYER   = "./cglc_lc_UTM_Himalaya.nc"

# %%
temp = xr.open_dataarray(TEMPERATURE_LAYER)
moist = xr.open_dataarray(MOISTURE_LAYER)
landform = xr.open_dataarray(LANDFORM_LAYER)
landcover = xr.open_dataarray(LANDCOVER_LAYER)
landcover_array  = np.copy(landcover.values)
landform_array  = np.copy(landform.values)
moisture_array  = np.copy(moist.values)
temperature_array  = np.copy(temp.values)

# %%
ecosystem_R  = np.ones(landcover_array.shape)*255
ecosystem_G  = np.ones(landcover_array.shape)*255
ecosystem_B  = np.ones(landcover_array.shape)*255

number_of_valid_pixels = np.count_nonzero(landcover_array)

ecosystem_map_global  = np.zeros(landcover_array.shape)

global_labels = {}

tot_class_numb = 0

for lc in range(1,9): # landcover
    lc_mask = landcover_array==lc
    color0 = wte_table.loc[wte_table['LC_Class']==lc]
    lc_class_value = lc
    for lf in range(1,6):
        lf_mask = landform_array==lf
        color1 = color0.loc[wte_table['LF_Class']==lf]
        lf_class_value = lf*10
        for mois in range(1,4):
            moist_mask = moisture_array==mois
            color2 = color1.loc[wte_table['MoistClass']==mois]
            moist_class_value = mois*100
            for t in range(0,6):
                temperature_mask = temperature_array==t
                if t==0:
                    color3 = color2.loc[wte_table['TempClass']==6]
                    temp_class_value = 6*1000
                else:
                    color3 = color2.loc[wte_table['TempClass']==t]
                    temp_class_value = t*1000
                try:
                    color3['WTE_HEX'].values[0]
                    rgb_color = hex_to_rgb(color3['WTE_HEX'].values[0])
                    ecosystem_label = color3['WEcosystm'].values[0]
                    ecosystem_mask = lc_mask*lf_mask*moist_mask*temperature_mask
                    if (np.sum(ecosystem_mask)>0):
                        tot_class_numb +=1
#                         if ((np.sum(ecosystem_mask) / number_of_valid_pixels)>0.01):
                        ecosystem_R[ecosystem_mask] = rgb_color[0]
                        ecosystem_G[ecosystem_mask] = rgb_color[1]
                        ecosystem_B[ecosystem_mask] = rgb_color[2]
                        ecosystem_class = temp_class_value + moist_class_value + lf_class_value + lc_class_value
                        ecosystem_map_global[ecosystem_mask] = ecosystem_class
                        global_labels[str(int(ecosystem_class))] = ecosystem_label
                except:
                    continue

global_ecosystem = np.stack([ecosystem_R,ecosystem_G,ecosystem_B],axis=2)

# %%
plt.imshow(global_ecosystem.astype(np.uint8),cmap='brg')

# %% [markdown]
# Compute the union of classes present in the WTE layer and the newly generated with global layers:

# %%
wte_global_classes = np.unique(np.concatenate([np.unique(ecosystem_map_wte),np.unique(ecosystem_map_global)])).astype(int)

# %% [markdown]
# Create a list with the corresponding class labels

# %%
wte_global_labels = []
for c in wte_global_classes:
    if c==0:
        wte_global_labels.append("NoClass")
        continue
    try:
        wte_global_labels.append(global_labels[str(c)])
    except:
        wte_global_labels.append(wte_labels[str(c)])

# %%
def plot_confusion_matrix(ax, cm, labels, normalize=True, cmap='Blues',true="WTE",predicted="predicted"):
    """Plot the confusion matrix ``cm``.
    Parameters
    ----------
    cm : :py:class:`numpy.ndarray`
        The confusion matrix.
    labels : `list` [`str`]
        Names of the classes.
    normalize : `bool`, optional
        Whether to normalize the confusion matrix. The default is `True`.
    figsize : `tuple` [`int`], optional
        The figure size in centimeters. The default is `(10, 10)`.
    cmap : `str`, optional
        A matplotlib colormap. The default is `'Blues'`.
    Returns
    -------
    fig : :py:class:`matplotlib.figure.Figure`
        An instance of :py:class:`matplotlib.figure.Figure`.
    ax : :py:class:`matplotlib.axes._subplots.AxesSubplot`
        An instance of :py:class:`matplotlib.axes._subplots.AxesSubplot`.
    """
    # number of classes
    nclasses = len(labels)

    # string format to plot values of confusion matrix
    fmt = '.0f'

    # minimum and maximum values of the colorbar
    vmin, vmax = 0, cm.max()

    # check whether to normalize the confusion matrix
    if normalize:
        # normalize
        norm = cm.sum(axis=1, keepdims=True)

        # check for division by zero
        norm[norm == 0] = 1
        cm = cm / norm

        # change string format to floating point
        fmt = '.2f'
        vmin, vmax = 0, 1

    # get colormap
    cmap = colormap.get_cmap(cmap, 256)

    # plot confusion matrix
    im = ax.imshow(cm, cmap=cmap, vmin=vmin, vmax=vmax)

    # threshold determining the color of the values
    thresh = (cm.max() + cm.min()) / 2

    # brightest/darkest color of current colormap
    cmap_min, cmap_max = cmap(0), cmap(256)

    # plot values of confusion matrix
    for i, j in itertools.product(range(nclasses), range(nclasses)):
        ax.text(j, i, format(cm[i, j], fmt), ha='center', va='center', color=cmap_max if cm[i, j] < thresh else cmap_min)

    # axes properties and labels
    ax.set(xticks=np.arange(nclasses),yticks=np.arange(nclasses),xticklabels=labels,yticklabels=labels,ylabel=true,xlabel=predicted)

    # rotate x-tick labels
    for label in ax.get_xticklabels():
        label.set_rotation(90)

    return

# %% [markdown]
# Plot the confusion matrix

# %%
cm_wte_global = confusion_matrix(ecosystem_map_wte.flatten(), ecosystem_map_global.flatten(), labels=list(wte_global_classes))
cm_wte_global = cm_wte_global[1:,1:]
fig, ax = plt.subplots(1,1,figsize=(30,30))
ax.set_title("WTE vs Global Confusion Matrix")
plot_confusion_matrix(ax,cm_wte_global,wte_global_labels[1:],true="WTE",predicted="Global",normalize=None)

# %% [markdown]
# Plot the normalized confusion matrix

# %%
cm_wte_global = confusion_matrix(ecosystem_map_wte.flatten(), ecosystem_map_global.flatten(), labels=list(wte_global_classes))
cm_wte_global = cm_wte_global[1:,1:]
fig, ax = plt.subplots(1,1,figsize=(30,30))
ax.set_title("WTE vs Global Confusion Matrix Normalized")
plot_confusion_matrix(ax,cm_wte_global,wte_global_labels[1:],true="WTE",predicted="Global",normalize=True)

# %%
pixel_size_km2 = 0.25*0.25 #We are working with a grid of 250m x 250m
diagonal = 0
wrong = 0
for i in range(cm_wte_global.shape[0]):
    for j in range(cm_wte_global.shape[1]):
        if i==j:
            diagonal += cm_wte_global[i,j]
        else:
            wrong += cm_wte_global[i,j]
data = {'Disagreement [km^2]':  [wrong*pixel_size_km2*pixel_size_km2],
        'Disagreement [%]': [wrong/(diagonal+wrong)*100],
        }
df = pd.DataFrame(data, columns = ['Disagreement [km^2]','Disagreement [%]'],
                        index=['WTE vs Global'])

df
# Out:
#                Disagreement [km^2]  Disagreement [%]
# WTE vs Global          1723.089844          62.97816

# %% [markdown]
# Masking operation for visualization

# %%
na_mask = np.where(wte_ecosystem[:,:,0]==255)
wte_ecosystem_masked = wte_ecosystem.copy()
wte_ecosystem_masked[global_ecosystem==255] = 0
wte_ecosystem[global_ecosystem==255] = 255
#WTE vs GLOBAL:
diff_wte_global = (np.mean(abs(wte_ecosystem - global_ecosystem),axis=2)>0).astype(float)

# %% [markdown]
# Define colors and labels for plotting:

# %%
colors_diff = ["#E0E0E0","#FFAA00"]
labels_diff = ["same","different"]
legend_diff = []
for i,x in enumerate(labels_diff):
    legend_diff.append(mpatches.Patch(color=colors_diff[i],label=x))

# %% [markdown]
# Create cmap for difference layer

# %%
diff_cmap = ListedColormap(["#E0E0E0","#FFAA00"])

# %% [markdown]
# Plot the results

# %%
wte_ecosystem = wte_ecosystem.astype(np.int16)
wte_ecosystem[global_ecosystem==255] = 255
global_ecosystem = global_ecosystem.astype(np.int16)
axis_xmin = landcover.x.min().values
axis_ymin = landcover.y.min().values
axis_xmax = landcover.x.max().values
axis_ymax = landcover.y.max().values
na_mask = np.where(wte_ecosystem[:,:,0]==255)

tmp_r = xr.ones_like(landcover)
tmp_g = xr.ones_like(landcover)
tmp_b = xr.ones_like(landcover)

tmp_r = (tmp_r * wte_ecosystem[:,:,0]).astype(np.uint8)
tmp_g = (tmp_g * wte_ecosystem[:,:,1]).astype(np.uint8)
tmp_b = (tmp_b * wte_ecosystem[:,:,2]).astype(np.uint8)
tmp_r['color'] = 'r'
tmp_g['color'] = 'g'
tmp_b['color'] = 'b'
tmp = xr.concat([tmp_r,tmp_g,tmp_b],dim='color')

fig, ax = plt.subplots(3,1,figsize=(6,15),gridspec_kw={'height_ratios': [1,1,1],'width_ratios': [1]})
tmp.plot.imshow(ax=ax[0],cmap='brg',extent=[axis_xmin,axis_xmax,axis_ymin,axis_ymax])
ax[0].set_title("WTE Ecosystems")

tmp_r = xr.ones_like(landcover)
tmp_g = xr.ones_like(landcover)
tmp_b = xr.ones_like(landcover)

tmp_r = (tmp_r * global_ecosystem[:,:,0]).astype(np.uint8)
tmp_g = (tmp_g * global_ecosystem[:,:,1]).astype(np.uint8)
tmp_b = (tmp_b * global_ecosystem[:,:,2]).astype(np.uint8)
tmp_r['color'] = 'r'
tmp_g['color'] = 'g'
tmp_b['color'] = 'b'
tmp = xr.concat([tmp_r,tmp_g,tmp_b],dim='color')

tmp.plot.imshow(ax=ax[1],cmap='brg',extent=[axis_xmin,axis_xmax,axis_ymin,axis_ymax])
ax[1].set_title("Global Layers Ecosystems")

tmp = xr.ones_like(landcover)
tmp = tmp * diff_wte_global
tmp = tmp.where(tmp<255)

tmp.plot.imshow(ax=ax[2],cmap=diff_cmap,extent=[axis_xmin,axis_xmax,axis_ymin,axis_ymax],add_colorbar=False)
ax[2].set_title("WTE vs Global Difference")
ax[2].legend(handles=legend_diff,loc='lower right')

# rotate y-tick labels

for k in ax:
    for label in k.get_yticklabels():
        label.set_rotation(90)
    
# remove all axis labels

for k in ax:
    k.set_xlabel("")
    k.set_ylabel("")  
    k.ticklabel_format(style='plain')

for k in ax[:2]:
    for i, tick in enumerate(k.xaxis.get_ticklabels()):
        tick.set_visible(False)
        
for k in ax:
    for i, tick in enumerate(k.yaxis.get_ticklabels()):
        if i%2==0:
            tick.set_visible(False)
            
plt.tight_layout()
plt.plot()
# Out:
# []

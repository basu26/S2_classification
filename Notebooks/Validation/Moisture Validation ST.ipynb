# %%
# Improt the necessary libraries
import itertools
import xarray as xr
import rasterio
import pandas as pd
import geopandas as gpd
import rioxarray
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import cm as colormap
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
import matplotlib.patches as mpatches
from sklearn.metrics import confusion_matrix
import numpy as np

# %%
# Filepaths

WTE_FOLDER = "/mnt/drive/AI4EBV/INPUTS/WTE/"
WTE_GLOBAL = "WTE1778.tif"

# Wte table

WTE_TABLE = WTE_FOLDER + "Tables/Realm_WE_attribute_Table_DraftSort.csv"

# South Tyrol shapefile

ST_SHP = "/mnt/drive/AI4EBV/BOUNDARIES/ST.shp"

# Output desired UTM Projection
# It is estimated automatically based on the provided shapefile. Needs to be tested in details. New PROJ version required >7
OUTPUT_CRS = "EPSG:32632"

# %% [markdown]
# Read the input WTE layer

# %%
wte_global = xr.open_rasterio(WTE_FOLDER + WTE_GLOBAL)
wte_global
# Out:
# <xarray.DataArray (band: 1, y: 3535, x: 6358)>
# [22475530 values with dtype=uint32]
# Coordinates:
#   * band     (band) int64 1
#   * y        (y) float64 50.1 50.1 50.1 50.1 50.1 ... 42.17 42.17 42.17 42.17
#   * x        (x) float64 3.643 3.645 3.647 3.649 ... 17.91 17.91 17.92 17.92
# Attributes:
#     transform:      (0.0022457989999999997, 0.0, 3.64154024832649, 0.0, -0.00...
#     crs:            +init=epsg:4326
#     res:            (0.0022457989999999997, 0.0022457989999999997)
#     is_tiled:       0
#     nodatavals:     (0.0,)
#     scales:         (1.0,)
#     offsets:        (0.0,)
#     AREA_OR_POINT:  Area
#     DataType:       Generic

# %% [markdown]
# Read the input shapefile

# %%
df = gpd.read_file(ST_SHP)
df
# Out:
#    COD_REG  COD_PRO       NOME_PRO     SHAPE_Leng    SHAPE_Area  \
# 0        4       21  BOLZANO/BOZEN  664283.497457  7.397682e+09
#
#                                             geometry
# 0  POLYGON ((743472.190 5219940.300, 743499.120 5...

# %%
df4326 = df.to_crs(4326)

# %%
df_buffer = df4326.copy()

# %%
delta = 0.1
minX = df_buffer.geometry.bounds['minx'] - delta
minY = df_buffer.geometry.bounds['miny'] - delta
maxX = df_buffer.geometry.bounds['maxx'] + delta
maxY = df_buffer.geometry.bounds['maxy'] + delta

# %%
wte_table = pd.read_csv(WTE_TABLE, sep=';')
wte_table
# Out:
#       RealmWE_ID  WE_ID  Realm_ID  RealmClass  LF_Class  MoistClass  \
# 0           1005      5      1000           1         1           3
# 1           1010     10      1000           1         3           3
# 2           1016     16      1000           1         2           3
# 3           1018     18      1000           1         1           3
# 4           1024     24      1000           1         3           3
# ...          ...    ...       ...         ...       ...         ...
# 1776        8399    399      8000           8         1           3
# 1777        8400    400      8000           8         3           1
# 1778        8406    406      8000           8         2           1
# 1779        8412    412      8000           8         3           1
# 1780        8417    417      8000           8         1           1
#
#       TempClass  LC_Class  Realm_Name     LF_Name                    LC_Name  \
# 0             6         6  Afrotropic   Mountains  Sparsley or Non vegetated
# 1             6         6  Afrotropic  Tablelands  Sparsley or Non vegetated
# 2             6         6  Afrotropic       Hills  Sparsley or Non vegetated
# 3             6         4  Afrotropic   Mountains                  Grassland
# 4             6         2  Afrotropic  Tablelands                  Shrubland
# ...         ...       ...         ...         ...                        ...
# 1776          3         8  Palearctic   Mountains               Snow and Ice
# 1777          4         3  Palearctic  Tablelands                     Forest
# 1778          5         3  Palearctic       Hills                     Forest
# 1779          5         2  Palearctic  Tablelands                  Shrubland
# 1780          5         3  Palearctic   Mountains                     Forest
#
#            Temp_Name Moist_Name            Temp_Moist  \
# 0              Polar      Moist           Polar Moist
# 1              Polar      Moist           Polar Moist
# 2              Polar      Moist           Polar Moist
# 3              Polar      Moist           Polar Moist
# 4              Polar      Moist           Polar Moist
# ...              ...        ...                   ...
# 1776  Warm Temperate      Moist  Warm Temperate Moist
# 1777    Sub Tropical     Desert   Sub Tropical Desert
# 1778        Tropical     Desert       Tropical Desert
# 1779        Tropical     Desert       Tropical Desert
# 1780        Tropical     Desert       Tropical Desert
#
#                                               WEcosystm  \
# 0     Polar Moist Sparsley or Non vegetated on Mount...
# 1     Polar Moist Sparsley or Non vegetated on Table...
# 2        Polar Moist Sparsley or Non vegetated on Hills
# 3                    Polar Moist Grassland on Mountains
# 4                   Polar Moist Shrubland on Tablelands
# ...                                                 ...
# 1776     Warm Temperate Moist Snow and Ice on Mountains
# 1777           Sub Tropical Desert Forest on Tablelands
# 1778                    Tropical Desert Forest on Hills
# 1779            Tropical Desert Shrubland on Tablelands
# 1780                Tropical Desert Forest on Mountains
#
#                                              RWEcosystm LandC_Type  Code
# 0     Afrotropic Polar Moist Sparsley or Non vegetat...    Natural  6316
# 1     Afrotropic Polar Moist Sparsley or Non vegetat...    Natural  6336
# 2     Afrotropic Polar Moist Sparsley or Non vegetat...    Natural  6326
# 3         Afrotropic Polar Moist Grassland on Mountains    Natural  6314
# 4        Afrotropic Polar Moist Shrubland on Tablelands    Natural  6332
# ...                                                 ...        ...   ...
# 1776  Palearctic Warm Temperate Moist Snow and Ice o...    Natural  3318
# 1777  Palearctic Sub Tropical Desert Forest on Table...    Natural  4133
# 1778         Palearctic Tropical Desert Forest on Hills    Natural  5123
# 1779  Palearctic Tropical Desert Shrubland on Tablel...    Natural  5132
# 1780     Palearctic Tropical Desert Forest on Mountains    Natural  5113
#
# [1781 rows x 18 columns]

# %% [markdown]
# # Moisture regime

# %%
WTE_MOISTURE_RULESET = "./moisture_ruleset.csv"
moisture_ruleset = pd.read_csv(WTE_MOISTURE_RULESET, sep=';')
moisture_ruleset
# Out:
#   WTE_moisture_domains aridity_index  WTE_moisture_domain_code
# 0                Moist         >0.65                         3
# 1                  Dry     0.05:0.65                         2
# 2               Desert         <0.05                         1

# %% [markdown]
# ## WTE Moisture Layer

# %%
wte_clipped = wte_global.rio.clip_box(minx=minX,miny=minY,maxx=maxX,maxy=maxY).astype(float)
max_value = wte_clipped.max().values
while(max_value>3):
    moistValue = wte_table.loc[wte_table['RealmWE_ID']==max_value]['MoistClass']
    if len(moistValue) != 0:
        wte_clipped = wte_clipped.where(wte_clipped!=max_value).fillna(int(moistValue))
    else:
        break
    max_value = wte_clipped.max().values
wte_clipped = wte_clipped.where(wte_clipped!=wte_clipped.attrs["_FillValue"])
wte_clipped = wte_clipped.where(wte_clipped!=7)
wte_clipped.attrs["_FillValue"] = np.nan

# %% [markdown]
# Define colors and labels for plotting:

# %%
moisture_cmap = {'Desert':"#F5F57A",'Dry':"#E68900",'Moist':"#728944"}
legend = []
for i,x in enumerate(moisture_ruleset['WTE_moisture_domain_code']):
    label = moisture_ruleset.loc[moisture_ruleset['WTE_moisture_domain_code']==x]['WTE_moisture_domains'].values[0]
    color = moisture_cmap[label]
    legend.append(mpatches.Patch(color=color,label=label))

colors_diff = ["#00375D","#0000CC","#00CCCC","#E0E0E0","#FFAA00","#CC0000","#660000"]
labels_diff = ["-3 zones","-2 zones","-1 zone","same zone","+1 zone","+2 zones","+3 zones"]
legend_diff = []
for i,x in enumerate(labels_diff):
    legend_diff.append(mpatches.Patch(color=colors_diff[i],label=x))

# %% [markdown]
# Create cmap for temperature layer

# %%
cmap_moist = ListedColormap(["#F5F57A","#E68900","#728944"])

# %% [markdown]
# Create cmap for difference layer

# %%
diff_cmap = ListedColormap(["#00375D","#0000CC","#00CCCC","#E0E0E0","#FFAA00","#CC0000","#660000"])

# %% [markdown]
# Reproject to the desired UTM projection:

# %%
#wte_moist_UTM = wte_clipped.rio.reproject(OUTPUT_CRS,resolution=250, resampling=0)
wte_moist_UTM = wte_clipped.rio.reproject(wte_clipped.rio.estimate_utm_crs(),resolution=250, resampling=0) # New Proj required
wte_moist_UTM = wte_moist_UTM.rio.clip(df.geometry, drop=True)

# %%
fig, ax = plt.subplots(figsize=(10,5))
fig = wte_moist_UTM[0].plot.imshow(ax=ax,cmap=cmap_moist,vmax=3, vmin=1)
ax.set_title("WTE Moisture Layer UTM")
ax.legend(handles=legend,loc='lower right')
ax.margins(10)
plt.plot()
# Out:
# []

# %%
wte_moist_UTM.attrs["_FillValue"] = np.nan

# %%
# wte_moist_UTM[0].to_netcdf("wte_moist_UTM_ST.nc")

# %% [markdown]
# ## CGIAR

# %%
CGIAR_ARIDITY_INDEX = "/mnt/drive/AI4EBV/INPUTS/CLIMATE/CGIAR/v2/ai_et0/ai_et0.tif"

# %% [markdown]
# Aridity Index

# %%
cgiar_aridity_ind = xr.open_rasterio(CGIAR_ARIDITY_INDEX,chunks=1000)
print(cgiar_aridity_ind)
# Out:
# <xarray.DataArray (band: 1, y: 18000, x: 43200)>
# dask.array<open_rasterio-2f4b2e5eb0134ac6a48322056a533cb7<this-array>, shape=(1, 18000, 43200), dtype=int32, chunksize=(1, 1000, 1000), chunktype=numpy.ndarray>
# Coordinates:
#   * band     (band) int64 1
#   * y        (y) float64 90.0 89.99 89.98 89.97 ... -59.97 -59.98 -59.99 -60.0
#   * x        (x) float64 -180.0 -180.0 -180.0 -180.0 ... 180.0 180.0 180.0 180.0
# Attributes:
#     transform:      (0.00833333333333333, 0.0, -180.0, 0.0, -0.00833333333333...
#     crs:            +init=epsg:4326
#     res:            (0.00833333333333333, 0.00833333333333333)
#     is_tiled:       1
#     nodatavals:     (-2147483647.0,)
#     scales:         (1.0,)
#     offsets:        (0.0,)
#     AREA_OR_POINT:  Area
#     DataType:       Generic

# %% [markdown]
# Clip the data to our region of interest

# %%
cgiar_aridity_ind_clipped = cgiar_aridity_ind.rio.clip_box(minx=minX,miny=minY,maxx=maxX,maxy=maxY)
cgiar_aridity_ind_clipped = cgiar_aridity_ind_clipped.where(cgiar_aridity_ind_clipped!=cgiar_aridity_ind_clipped.attrs["_FillValue"])
cgiar_aridity_ind_clipped.attrs["_FillValue"] = np.nan
cgiar_aridity_ind_clipped = (cgiar_aridity_ind_clipped/10000).compute()

# %% [markdown]
# Reprojection to 250m in UTM with cubic interpolation

# %%
cgiar_aridity_ind_clipped = cgiar_aridity_ind_clipped.rio.reproject_match(wte_moist_UTM,2)
cgiar_aridity_ind_clipped = cgiar_aridity_ind_clipped.rio.clip(df.geometry, drop=True)
cgiar_aridity_ind_clipped = cgiar_aridity_ind_clipped.where(cgiar_aridity_ind_clipped!=cgiar_aridity_ind_clipped.attrs["_FillValue"])
cgiar_aridity_ind_clipped.attrs["_FillValue"] = np.nan

# %%
fig, ax = plt.subplots()
(cgiar_aridity_ind_clipped[0]).plot.imshow(ax=ax)
ax.set_title("CIAR Aridity Index")
plt.plot()
# Out:
# []

# %% [markdown]
# Classification of CGIAR according to the WTE scheme

# %%
# Create a NaN mask
na_mask = np.bitwise_not(xr.ufuncs.isnan(cgiar_aridity_ind_clipped))
# Create the output layer
cgiar_to_wte = xr.zeros_like(cgiar_aridity_ind_clipped)

# %%
# Moist (Humid): WTE domain code = 3
cgiar_to_wte = cgiar_to_wte + (cgiar_aridity_ind_clipped>0.65)*3
# Dry (Arid):  WTE domain code = 2
cgiar_to_wte = cgiar_to_wte + (np.bitwise_and(cgiar_aridity_ind_clipped>=0.05,cgiar_aridity_ind_clipped<=0.65))*2
# Desert (Hyperarid): WTE domain code = 1
cgiar_to_wte = cgiar_to_wte + (cgiar_aridity_ind_clipped<0.05)*1
# Apply NaNs mask
cgiar_to_wte = cgiar_to_wte.where(na_mask)

# %%
fig, ax = plt.subplots(figsize=(10,5))
fig = cgiar_to_wte[0].plot.imshow(ax=ax,cmap=cmap_moist,vmax=3, vmin=1)
ax.set_title("CGIAR Moisture Layer UTM")
ax.legend(handles=legend,loc='lower right')
ax.margins(10)
plt.plot()
# Out:
# []

# %%
# cgiar_to_wte[0].to_netcdf("cgiar_to_wte_moist_UTM_ST.nc")

# %% [markdown]
# Combine the NaN masks and mask the data to avoid not overlapping pixels due to reprojection:

# %%
na_mask = np.bitwise_not(np.bitwise_or(xr.ufuncs.isnan(wte_moist_UTM),xr.ufuncs.isnan(cgiar_to_wte)))
wte_moist_UTM_masked_cgiar = wte_moist_UTM.where(na_mask)
cgiar_to_wte_UTM_masked = cgiar_to_wte.where(na_mask)

# %% [markdown]
# Now that we have both moisture layers with the same class scheme and projection we can compute the difference:

# %%
wte_cgiar_diff = wte_moist_UTM_masked_cgiar - cgiar_to_wte_UTM_masked

# %%
fig, ax = plt.subplots()
wte_cgiar_diff[0].plot.imshow(ax=ax)
ax.set_title("WTE vs CGIAR diff in UTM")
plt.plot()
# Out:
# []

# %% [markdown]
# ## Chelsa 1.2

# %%
CHELSA_ROOT = "/mnt/drive/AI4EBV/INPUTS/CLIMATE/CHELSA/"
CHELSA_ANNUAL_PRECIPITATION = CHELSA_ROOT + "CHELSA_bio10_12.tif"
CHELSA_POT_EVAPOTRANSPIRATION = CHELSA_ROOT + "CHELSA_pet_annual_mean_1979-2013.tif"

# %% [markdown]
# The UNEP has adopted yet another index of aridity, defined as:
#
# ![image.png](attachment:463d4c60-1094-45b6-9410-67b971d48141.png)
#
# where PET is the potential evapotranspiration and P is the average annual precipitation (UNEP, 1992).

# %% [markdown]
# Aridity Index

# %%
chelsa_annual_prec = xr.open_rasterio(CHELSA_ANNUAL_PRECIPITATION,chunks=1000).rio.clip_box(minx=minX,miny=minY,maxx=maxX,maxy=maxY)
chelsa_annual_prec = chelsa_annual_prec.where(chelsa_annual_prec!=chelsa_annual_prec.attrs["_FillValue"])
chelsa_annual_prec.attrs["_FillValue"] = np.nan
chelsa_pot_evap    = xr.open_rasterio(CHELSA_POT_EVAPOTRANSPIRATION,chunks=1000).rio.clip_box(minx=minX,miny=minY,maxx=maxX,maxy=maxY)
chelsa_pot_evap = chelsa_pot_evap.where(chelsa_pot_evap!=chelsa_pot_evap.attrs["_FillValue"])
chelsa_pot_evap.attrs["_FillValue"] = np.nan
# Out:
# /home/euracuser/miniconda3/envs/pysegcnn/lib/python3.7/site-packages/rioxarray/raster_writer.py:109: UserWarning: The nodata value (-3.4e+38) has been automatically changed to (-3.3999999521443642e+38) to match the dtype of the data.
#   f"The nodata value ({original_nodata}) has been automatically "

# %% [markdown]
# The data has sligtly differences in the coordinates due to rounding errors. Before being able to combine the data we need to align them:

# %%
chelsa_annual_prec['x'] = chelsa_annual_prec.x.astype(np.float32)
chelsa_annual_prec['y'] = chelsa_annual_prec.y.astype(np.float32)
chelsa_pot_evap['x'] = chelsa_pot_evap.x.astype(np.float32)
chelsa_pot_evap['y'] = chelsa_pot_evap.y.astype(np.float32)

# %%
chelsa_aridity_ind = (chelsa_annual_prec / chelsa_pot_evap).compute()

# %% [markdown]
# Reprojection to 250m in UTM with cubic interpolation

# %%
chelsa_aridity_ind = chelsa_aridity_ind.rio.reproject_match(wte_moist_UTM,2)
chelsa_aridity_ind = chelsa_aridity_ind.rio.clip(df.geometry, drop=True)
chelsa_aridity_ind = chelsa_aridity_ind.where(chelsa_aridity_ind!=chelsa_aridity_ind.attrs["_FillValue"])
chelsa_aridity_ind.attrs["_FillValue"] = np.nan

# %%
fig, ax = plt.subplots()
chelsa_aridity_ind[0].plot.imshow(ax=ax)
ax.set_title("Chelsa Aridity Index")
plt.plot()
# Out:
# []

# %% [markdown]
# Classification of Chelsa according to the WTE scheme

# %%
# Create a NaN mask
na_mask = np.bitwise_not(xr.ufuncs.isnan(chelsa_aridity_ind))
# Create the output layer
chelsa_to_wte = xr.zeros_like(chelsa_aridity_ind)

# %%
# Moist (Humid): WTE domain code = 3
chelsa_to_wte = chelsa_to_wte + (chelsa_aridity_ind>0.65)*3
# Dry (Arid):  WTE domain code = 2
chelsa_to_wte = chelsa_to_wte + (np.bitwise_and(chelsa_aridity_ind>=0.05,chelsa_aridity_ind<=0.65))*2
# Desert (Hyperarid): WTE domain code = 1
chelsa_to_wte = chelsa_to_wte + (chelsa_aridity_ind<0.05)*1
# Apply NaNs mask
chelsa_to_wte = chelsa_to_wte.where(na_mask)

# %%
fig, ax = plt.subplots(figsize=(10,5))
fig = chelsa_to_wte[0].plot.imshow(ax=ax,cmap=cmap_moist,vmax=3, vmin=1)
ax.set_title("CHELSA 1.2 Moisture Layer UTM")
ax.legend(handles=legend,loc='lower right')
ax.margins(10)
plt.plot()
# Out:
# []

# %%
# chelsa_to_wte[0].to_netcdf("chelsa_to_wte_moist_UTM_ST.nc")

# %% [markdown]
# Combine the NaN masks and mask the data to avoid not overlapping pixels due to reprojection:

# %%
na_mask = np.bitwise_not(np.bitwise_or(xr.ufuncs.isnan(wte_moist_UTM),xr.ufuncs.isnan(chelsa_to_wte)))
wte_moist_UTM_masked_chelsa = wte_moist_UTM.where(na_mask)
chelsa_to_wte_UTM_masked = chelsa_to_wte.where(na_mask)

# %% [markdown]
# Now that we have both temperature layers with the same class scheme and projection we can compute the difference:

# %%
wte_chelsa_diff = wte_moist_UTM_masked_chelsa - chelsa_to_wte_UTM_masked

# %%
fig, ax = plt.subplots()
wte_chelsa_diff[0].plot.imshow(ax=ax)
ax.set_title("WTE vs Chelsa 1.2 diff in UTM")
plt.plot()
# Out:
# []

# %% [markdown]
# ## EURAC

# %%
EURAC_ROOT = "/mnt/drive/AI4EBV/INPUTS/CLIMATE/EURAC/"

EURAC_ANNUAL_PRECIPITATION = EURAC_ROOT + "PREC_1980_2010.tif"
EURAC_POT_EVAPOTRANSPIRATION = EURAC_ROOT + "PET_1980_2010.tif"

# %% [markdown]
# Aridity Index

# %%
eurac_annual_prec = xr.open_rasterio(EURAC_ANNUAL_PRECIPITATION,chunks=1000)
eurac_pot_evap    = xr.open_rasterio(EURAC_POT_EVAPOTRANSPIRATION,chunks=1000)

# %%
eurac_aridity_ind = (eurac_annual_prec / eurac_pot_evap).compute()

# %%
# Create a NaN mask
na_mask = np.bitwise_not(xr.ufuncs.isnan(eurac_annual_prec))
# Create the output layer
eurac_aridity_ind = eurac_aridity_ind.where(na_mask)
eurac_aridity_ind = eurac_aridity_ind.where(eurac_aridity_ind>0)

# %% [markdown]
# Reprojection to 250m in UTM with cubic interpolation

# %%
eurac_aridity_ind = eurac_aridity_ind.rio.write_crs('EPSG:32632')
eurac_aridity_ind = eurac_aridity_ind.rio.reproject_match(wte_moist_UTM,2)
eurac_aridity_ind = eurac_aridity_ind.rio.clip(df.geometry, drop=True)
eurac_aridity_ind = eurac_aridity_ind.where(eurac_aridity_ind!=eurac_aridity_ind.attrs["_FillValue"])
eurac_aridity_ind.attrs["_FillValue"] = np.nan
eurac_aridity_ind = eurac_aridity_ind.where(eurac_aridity_ind<3.e+38) # Remove nan numbers from the interpolation
# Out:
# /home/euracuser/miniconda3/envs/pysegcnn/lib/python3.7/site-packages/rioxarray/raster_writer.py:109: UserWarning: The nodata value (3.402823466e+38) has been automatically changed to (3.4028234663852886e+38) to match the dtype of the data.
#   f"The nodata value ({original_nodata}) has been automatically "

# %%
fig, ax = plt.subplots()
eurac_aridity_ind[0].plot.imshow(ax=ax)
ax.set_title("EURAC Aridity Index")
plt.plot()
# Out:
# []

# %% [markdown]
# Classification of Chelsa according to the WTE scheme

# %%
# Create a NaN mask
na_mask = np.bitwise_not(xr.ufuncs.isnan(eurac_aridity_ind))
# Create the output layer
eurac_to_wte = xr.zeros_like(eurac_aridity_ind)

# %%
# Moist (Humid): WTE domain code = 3
eurac_to_wte = eurac_to_wte + (eurac_aridity_ind>0.65)*3
# Dry (Arid):  WTE domain code = 2
eurac_to_wte = eurac_to_wte + (np.bitwise_and(eurac_aridity_ind>=0.05,eurac_aridity_ind<=0.65))*2
# Desert (Hyperarid): WTE domain code = 1
eurac_to_wte = eurac_to_wte + (eurac_aridity_ind<0.05)*1
# Apply NaNs mask
eurac_to_wte = eurac_to_wte.where(na_mask)

# %%
fig, ax = plt.subplots(figsize=(10,5))
fig = eurac_to_wte[0].plot.imshow(ax=ax,cmap=cmap_moist,vmax=3, vmin=1)
ax.set_title("EURAC Moisture Layer UTM")
ax.legend(handles=legend,loc='lower right')
ax.margins(10)
plt.plot()
# Out:
# []

# %%
# eurac_to_wte[0].to_netcdf("eurac_to_wte_moist_UTM_ST.nc")

# %% [markdown]
# Combine the NaN masks and mask the data to avoid not overlapping pixels due to reprojection:

# %%
na_mask = np.bitwise_not(np.bitwise_or(xr.ufuncs.isnan(wte_moist_UTM),xr.ufuncs.isnan(eurac_to_wte)))
wte_moist_UTM_masked_eurac = wte_moist_UTM.where(na_mask)
eurac_to_wte_UTM_masked = eurac_to_wte.where(na_mask)

# %% [markdown]
# Now that we have both temperature layers with the same class scheme and projection we can compute the difference:

# %%
wte_eurac_diff = wte_moist_UTM_masked_eurac - eurac_to_wte_UTM_masked

# %%
fig, ax = plt.subplots()
wte_eurac_diff[0].plot.imshow(ax=ax)
ax.set_title("WTE vs EURAC diff in UTM")
plt.plot()
# Out:
# []

# %% [markdown]
# Compute the difference between the regional EURAC layer with the global ones

# %%
#EURAC vs CGIAR:
na_mask = np.bitwise_not(np.bitwise_or(xr.ufuncs.isnan(eurac_to_wte),xr.ufuncs.isnan(cgiar_to_wte[0])))
# cgiar_to_wte_UTM_masked = cgiar_to_wte[0].where(na_mask)
eurac_to_wte_UTM_masked     = eurac_to_wte.where(na_mask).drop('band')
eurac_cgiar_diff = eurac_to_wte_UTM_masked - cgiar_to_wte_UTM_masked
#EURAC vs CHELSA:
na_mask = np.bitwise_not(np.bitwise_or(xr.ufuncs.isnan(eurac_to_wte),xr.ufuncs.isnan(chelsa_to_wte[0])))
# chelsa_to_wte_UTM_masked = chelsa_to_wte[0].where(na_mask)
eurac_to_wte_UTM_masked  = eurac_to_wte.where(na_mask).drop('band')
eurac_chelsa_diff = eurac_to_wte_UTM_masked - chelsa_to_wte_UTM_masked

# %% [markdown]
# Table resuming the correspondence between the data
# 1. Compute the number of pixels which are non zero
# 2. Compute the percentage and the area in km^2 of the difference

# %%
#WTE vs CGIAR:
wte_cgiar_diff_km2 = np.count_nonzero(wte_cgiar_diff.fillna(0).astype(np.int8)) * (0.25**2) #Area in km^2
wte_cgiar_diff_dis = np.count_nonzero(wte_cgiar_diff.fillna(0))/np.count_nonzero(~np.isnan(wte_cgiar_diff))*100 #Percentage of disagreement
#WTE vs CHELSA:
wte_chelsa_diff_km2 = np.count_nonzero(wte_chelsa_diff.fillna(0).astype(np.int8)) * (0.25**2) #Area in km^2
wte_chelsa_diff_dis = np.count_nonzero(wte_chelsa_diff.fillna(0))/np.count_nonzero(~np.isnan(wte_chelsa_diff))*100 #Percentage of disagreement
#WTE vs EURAC:
wte_eurac_diff_km2 = np.count_nonzero(wte_eurac_diff.fillna(0).astype(np.int8)) * (0.25**2) #Area in km^2
wte_eurac_diff_dis = np.count_nonzero(wte_eurac_diff.fillna(0))/np.count_nonzero(~np.isnan(wte_eurac_diff))*100 #Percentage of disagreement
#EURAc vs CGIAR:
eurac_cgiar_diff_km2 = np.count_nonzero(eurac_cgiar_diff.fillna(0).astype(np.int8)) * (0.25**2) #Area in km^2
eurac_cgiar_diff_dis = np.count_nonzero(eurac_cgiar_diff.fillna(0))/np.count_nonzero(~np.isnan(eurac_cgiar_diff))*100 #Percentage of disagreement
#EURAC vs CHELSA:
eurac_chelsa_diff_km2 = np.count_nonzero(eurac_chelsa_diff.fillna(0).astype(np.int8)) * (0.25**2) #Area in km^2
eurac_chelsa_diff_dis = np.count_nonzero(eurac_chelsa_diff.fillna(0))/np.count_nonzero(~np.isnan(eurac_chelsa_diff))*100 #Percentage of disagreement

# %%
wte_cgiar_diff[0].plot.imshow()

# %%
import pandas as pd

data = {'Disagreement [km^2]':  [wte_cgiar_diff_km2, wte_chelsa_diff_km2,wte_eurac_diff_km2,eurac_cgiar_diff_km2,eurac_chelsa_diff_km2],
        'Disagreement [%]': [wte_cgiar_diff_dis, wte_chelsa_diff_dis,wte_eurac_diff_dis,eurac_cgiar_diff_dis,eurac_chelsa_diff_dis],
        }

df = pd.DataFrame(data, columns = ['Disagreement [km^2]','Disagreement [%]'],
                        index=['WTE vs CGIAR','WTE vs Chelsa 2.1','WTE vs EURAC','EURAC vs CGIAR','EURAC vs Chelsa 2.1'])

df
# Out:
#                      Disagreement [km^2]  Disagreement [%]
# WTE vs CGIAR                    885.1875         11.990958
# WTE vs Chelsa 2.1                 0.0000          0.000000
# WTE vs EURAC                      0.0000          0.000000
# EURAC vs CGIAR                  885.1875         12.569334
# EURAC vs Chelsa 2.1               0.0000          0.000000

# %%
def plot_confusion_matrix(ax, cm, labels, normalize=True, cmap='Blues',true="WTE",predicted="predicted"):
    """Plot the confusion matrix ``cm``.
    Parameters
    ----------
    cm : :py:class:`numpy.ndarray`
        The confusion matrix.
    labels : `list` [`str`]
        Names of the classes.
    normalize : `bool`, optional
        Whether to normalize the confusion matrix. The default is `True`.
    figsize : `tuple` [`int`], optional
        The figure size in centimeters. The default is `(10, 10)`.
    cmap : `str`, optional
        A matplotlib colormap. The default is `'Blues'`.
    Returns
    -------
    fig : :py:class:`matplotlib.figure.Figure`
        An instance of :py:class:`matplotlib.figure.Figure`.
    ax : :py:class:`matplotlib.axes._subplots.AxesSubplot`
        An instance of :py:class:`matplotlib.axes._subplots.AxesSubplot`.
    """
    # number of classes
    nclasses = len(labels)

    # string format to plot values of confusion matrix
    fmt = '.0f'

    # minimum and maximum values of the colorbar
    vmin, vmax = 0, cm.max()

    # check whether to normalize the confusion matrix
    if normalize:
        # normalize
        norm = cm.sum(axis=1, keepdims=True)

        # check for division by zero
        norm[norm == 0] = 1
        cm = cm / norm

        # change string format to floating point
        fmt = '.2f'
        vmin, vmax = 0, 1

    # get colormap
    cmap = colormap.get_cmap(cmap, 256)

    # plot confusion matrix
    im = ax.imshow(cm, cmap=cmap, vmin=vmin, vmax=vmax)

    # threshold determining the color of the values
    thresh = (cm.max() + cm.min()) / 2

    # brightest/darkest color of current colormap
    cmap_min, cmap_max = cmap(0), cmap(256)

    # plot values of confusion matrix
    for i, j in itertools.product(range(nclasses), range(nclasses)):
        ax.text(j, i, format(cm[i, j], fmt), ha='center', va='center', color=cmap_max if cm[i, j] < thresh else cmap_min)

    # axes properties and labels
    ax.set(xticks=np.arange(nclasses),yticks=np.arange(nclasses),xticklabels=labels,yticklabels=labels,ylabel=true,xlabel=predicted)

    # rotate x-tick labels
    for label in ax.get_xticklabels():
        label.set_rotation(90)

    return

# %%
axis_xmin = wte_moist_UTM_masked_cgiar.x.min().values
axis_ymin = wte_moist_UTM_masked_cgiar.y.min().values
axis_xmax = wte_moist_UTM_masked_cgiar.x.max().values
axis_ymax = wte_moist_UTM_masked_cgiar.y.max().values

moisture_labels = ['Desert','Dry','Moist']

fig, ax = plt.subplots(3,3,figsize=(15,15))
fig = wte_moist_UTM_masked_cgiar[0].plot.imshow(ax=ax[0,0],cmap=cmap_moist,vmax=3, vmin=1,add_colorbar=False,extent=[axis_xmin,axis_xmax,axis_ymin,axis_ymax])
ax[0,0].set_title("WTE Moisture")
ax[0,0].legend(handles=legend,loc='lower right')
fig = wte_moist_UTM_masked_chelsa[0].plot.imshow(ax=ax[0,1],cmap=cmap_moist,vmax=3, vmin=1,add_colorbar=False,extent=[axis_xmin,axis_xmax,axis_ymin,axis_ymax])
ax[0,1].set_title("WTE Moisture")
ax[0,1].legend(handles=legend,loc='lower right')
fig = wte_moist_UTM_masked_eurac[0].plot.imshow(ax=ax[0,2],cmap=cmap_moist,vmax=3, vmin=1,add_colorbar=False,extent=[axis_xmin,axis_xmax,axis_ymin,axis_ymax])
ax[0,2].set_title("WTE Moisture")
ax[0,2].legend(handles=legend,loc='lower right')

fig = cgiar_to_wte_UTM_masked[0].plot.imshow(ax=ax[1,0],cmap=cmap_moist,vmax=3, vmin=1,add_colorbar=False,extent=[axis_xmin,axis_xmax,axis_ymin,axis_ymax])
ax[1,0].set_title("CGIAR Moisture")
ax[1,0].legend(handles=legend,loc='lower right')
fig = chelsa_to_wte_UTM_masked[0].plot.imshow(ax=ax[1,1],cmap=cmap_moist,vmax=3, vmin=1,add_colorbar=False,extent=[axis_xmin,axis_xmax,axis_ymin,axis_ymax])
ax[1,1].set_title("Chelsa 1.2 Moisture")
ax[1,1].legend(handles=legend,loc='lower right')
fig = eurac_to_wte_UTM_masked[0].plot.imshow(ax=ax[1,2],cmap=cmap_moist,vmax=3, vmin=1,add_colorbar=False,extent=[axis_xmin,axis_xmax,axis_ymin,axis_ymax])
ax[1,2].set_title("EURAC Moisture")
ax[1,2].legend(handles=legend,loc='lower right')

fig = wte_cgiar_diff[0].plot.imshow(ax=ax[2,0],cmap=diff_cmap,vmax=3, vmin=-3,add_colorbar=False,extent=[axis_xmin,axis_xmax,axis_ymin,axis_ymax])
ax[2,0].set_title("WTE - CGIAR Agreement")
ax[2,0].legend(handles=legend_diff,loc='lower right')
fig = wte_chelsa_diff[0].plot.imshow(ax=ax[2,1],cmap=diff_cmap,vmax=3, vmin=-3,add_colorbar=False,extent=[axis_xmin,axis_xmax,axis_ymin,axis_ymax])
ax[2,1].set_title("WTE - Chelsa 1.2 Agreement")
ax[2,1].legend(handles=legend_diff,loc='lower right')
fig = wte_eurac_diff[0].plot.imshow(ax=ax[2,2],cmap=diff_cmap,vmax=3, vmin=-3,add_colorbar=False,extent=[axis_xmin,axis_xmax,axis_ymin,axis_ymax])
ax[2,2].set_title("WTE - EURAC Agreement")
ax[2,2].legend(handles=legend_diff,loc='lower right')

# rotate y-tick labels
for i in ax[:3]:
    for k in i[:]:
        for label in k.get_yticklabels():
            label.set_rotation(90)
    
# remove all axis labels
for i in ax[:3]:
    for k in i[:]:
        k.set_xlabel("")
        k.set_ylabel("")  
        k.ticklabel_format(style='plain')
for i in ax[:2]:
    for k in i[:]:
        for i, tick in enumerate(k.xaxis.get_ticklabels()):
            tick.set_visible(False)
for i in ax[:]:
    for k in i[1:]:
        for i, tick in enumerate(k.yaxis.get_ticklabels()):
            tick.set_visible(False)

plt.tight_layout()
plt.plot()
# Out:
# []

# %%
moisture_labels = ['Desert','Dry','Moist']

fig, ax = plt.subplots(1,3,figsize=(15,20))

cm_cgiar = confusion_matrix(wte_moist_UTM_masked_cgiar[0].fillna(-999).values.flatten(), cgiar_to_wte_UTM_masked[0].fillna(-999).values.flatten(), labels=[-999,1,2,3])
cm_cgiar = cm_cgiar[1:,1:]
plot_confusion_matrix(ax[0],cm_cgiar,[1,2,3],true="WTE",predicted="CGIAR",normalize=None)
ax[0].set_xticklabels(moisture_labels)
ax[0].set_yticklabels(moisture_labels)
ax[0].set_title("Confusion Matrix WTE - CGIAR")

cm_chelsa = confusion_matrix(wte_moist_UTM_masked_chelsa[0].fillna(-999).values.flatten(), chelsa_to_wte_UTM_masked[0].fillna(-999).values.flatten(), labels=[-999,1,2,3])
cm_chelsa = cm_chelsa[1:,1:]
plot_confusion_matrix(ax[1],cm_chelsa,[1,2,3],true="WTE",predicted="Chelsa 1.2",normalize=None)
ax[1].set_xticklabels(moisture_labels)
ax[1].set_yticklabels(moisture_labels)
ax[1].set_title("Confusion Matrix WTE - Chelsa 1.2")

cm_eurac = confusion_matrix(wte_moist_UTM_masked_eurac.fillna(-999).values.flatten(), eurac_to_wte_UTM_masked.fillna(-999).values.flatten(), labels=[-999,1,2,3])
cm_eurac = cm_eurac[1:,1:]
plot_confusion_matrix(ax[2],cm_eurac,[1,2,3],true="WTE",predicted="EURAC",normalize=None)
ax[2].set_xticklabels(moisture_labels)
ax[2].set_yticklabels(moisture_labels)
ax[2].set_title("Confusion Matrix WTE - EURAC")


plt.tight_layout()
plt.plot()
# Out:
# []
